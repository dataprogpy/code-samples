# %% [markdown]
# <a href="https://colab.research.google.com/github/dataprogpy/code-samples/blob/main/demo_notebooks/03_data_wrangling_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# 1. Data wrangling: what & why
# 1. Polars & Pandas
#   - install and import
#   - Polars Overview
# 1. Reading Data
#   - `customers.csv` & `orders.csv`
#   - Getting to know schema
# 1. Exploring Data
# 1. Polars Concepts
#   - Series
#   - DataFrame
#   - Expressions
#   - ExecutionContext
#   - LazyFrame
# 1. Data transformation
#   - selecting columns
#   - filtering rows
#   - renaming columns
#   - casting
#   - enums and cats
#   - missing value
# 1. Aggregation
#   - group_by execution context
#   - split-apply-combine
# 1. Stitching data together
#   - join
#   - concat

# %%
import polars as pl

# Define the desired schema for selected columns
customer_schema = {
    'customer_id': pl.Int32,        # Specify as 32-bit integer
    'name': pl.Utf8,                # Explicitly Utf8 (string)
    'registration_date': pl.Utf8,   # Read as string; parsing will be handled later due to mixed formats
    'city': pl.Categorical,         # Use Categorical for columns with repetitive string values
    'age': pl.Float32               # Use Float32 for age (e.g., if non-integer ages were possible or for consistency)
}

# Load the customers dataset with the specified schema
customers_custom_schema_df = pl.read_csv('customers.csv', dtypes=customer_schema)

customers_custom_schema_df.dtypes
print("\n")
customers_custom_schema_df.head()
# Out:
# <ipython-input-7-9cf84d3a29d5>:13: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   customers_custom_schema_df = pl.read_csv('customers.csv', dtypes=customer_schema)
# [Int32, String, String, Categorical(ordering='physical'), Float32]
# shape: (5, 5)
# ┌─────────────┬──────────────────┬───────────────────┬──────────┬────────┐
# │ customer_id ┆ name             ┆ registration_date ┆ city     ┆ age    │
# │ ---         ┆ ---              ┆ ---               ┆ ---      ┆ ---    │
# │ i32         ┆ str              ┆ str               ┆ cat      ┆ f32    │
# ╞═════════════╪══════════════════╪═══════════════════╪══════════╪════════╡
# │ 101         ┆ Alice Wonderland ┆ 2022-01-15        ┆ New York ┆ 28.0   │
# │ 102         ┆ Bob The Builder  ┆ 2022-03-22        ┆ London   ┆ 35.0   │
# │ 103         ┆ Charlie Brown    ┆ 2022-05-10        ┆ Paris    ┆ 45.0   │
# │ 104         ┆ Diana Prince     ┆ 2022-07-01        ┆ New York ┆ 3000.0 │
# │ 105         ┆ Evan Almighty    ┆ 2022-08-19        ┆ London   ┆ 42.0   │
# └─────────────┴──────────────────┴───────────────────┴──────────┴────────┘
