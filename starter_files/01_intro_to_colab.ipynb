# %% [markdown]
# <a href="https://colab.research.google.com/github/dataprogpy/code-samples/blob/main/starter_files/01_intro_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **I. Welcome to Colab: Your Data Science Playground**

# %% [markdown]
# ## **A. What is Colab and Why Use It?**
#
# Welcome to Google Colaboratory, or "Colab" for short!
#
# Think of Colab as your interactive, cloud-based notebook for working with Python, a powerful language widely used in data science. It runs entirely in your web browser, requiring **no complex setup** on your computer.
#
# **Why is Colab valuable for you as an MBA student?**
#
# * **Zero Configuration:** Get started immediately with powerful computing resources, including access to GPUs and TPUs for more advanced tasks later on.
# * **Easy Collaboration & Sharing:** Just like Google Docs, you can easily share your Colab notebooks with classmates or instructors for viewing, commenting, or co-editing.
# * **Integrated with Google Drive:** Save your work, access datasets, and manage your projects seamlessly within your Google Drive.
# * **Industry Standard Tool:** Familiarity with notebook environments like Colab (and its open-source counterpart, Jupyter Notebook) is a valuable skill in data-related roles.
# * **Hands-on Learning:** It's the perfect environment to learn and apply data analysis techniques. You'll be able to wrangle diverse datasets (using libraries like **Polars**), create insightful visualizations (with **Altair**), build predictive models (using **scikit-learn**), and even explore advanced data types like **time series and text** – all geared towards deriving insights for **data-driven decision-making** in business.
#
# In this course, we'll use Colab as our primary platform to explore these tools and concepts.

# %% [markdown]
# ## **B. Learning Objectives for This Session**
#
# By the end of this introductory session and after working through this notebook, you will be able to:
#
# * Understand the basic components of the Colab interface.
# * Create and run **text cells** (for notes and explanations, using Markdown for formatting) and **code cells** (for executing Python code).
# * Perform simple calculations and variable assignments in Python.
# * Effectively use Colab's **help features** to find information and troubleshoot.
# * Understand how Colab handles **files**, including temporary session storage and mounting your **Google Drive** for persistent work.
# * Grasp the concept of the **kernel**, why execution order matters, and how to reset the kernel state to avoid common pitfalls.
# * Practice basic **debugging** techniques.
#
# **Let's get started!**

# %% [markdown]
# #  Introduction to Colab: Agenda
#
# 1. Colab UI orientation
# 1. The help hierarchy
# 1. Working with files
# 1. Understanding kernel and kernel state
# 1. Let's debug! (Applying the Help hierarchy
# 1. Things to try
# 1. What's next

# %% [markdown]
# ## Colab User Interface
#
# ### Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.
#
# ### Code & Text Cells
# In a notebook

# %% [markdown]
# ### Code cells
# Below is a **code cell**. Once the toolbar button indicates CONNECTED, click in the cell to select it and execute the contents in the following ways:
#
# * Click the **Play icon** in the left gutter of the cell;
# * Type **Cmd/Ctrl+Enter** to run the cell in place;
# * Type **Shift+Enter** to run the cell and move focus to the next cell (adding one if none exists); or
# * Type **Alt+Enter** to run the cell and insert a new code cell immediately below it.
#
# There are additional options for running some or all cells in the **Runtime** menu.

# %%
def greet_user(greetings: str, name: str) -> None:
  """Prints a personalized greeting.

  This function takes a greeting string and a name string as input
  and prints a combined greeting message to the console.

  Args:
    greetings: The greeting phrase to use (e.g., "Hello", "Hi", "Good morning").
    name: The name of the person to greet.

  Returns:
    None
  """
  print(f"{greetings}, {name}!")

# %%
# Example usage:
greet_user("Hello", "Alice")
greet_user("Good morning", "Bob")
# Out:
# Hello, Alice!
# Good morning, Bob!

# %% [markdown]
# ### Text cells
# This is a **text cell**. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).

# %% [markdown]
# ### Adding and moving cells
# You can add new cells by using the **+ CODE** and **+ TEXT** buttons that show when you hover between cells. These buttons are also in the **toolbar** above the notebook where they can be used to add a cell below the currently selected cell.
#
# You can move a cell by selecting it and clicking ⬆ or ⬇ in the cell toolbar that appears on the top right corner of an active cell.

# %% [markdown]
# ## Help Hierarchy

# %% [markdown]
# ### Automatic completions and exploring code
#
# Colab provides automatic completions to explore attributes of Python objects, as well as to quickly view documentation strings. As an example, first run the following cell to import the  [`numpy`](http://www.numpy.org) module.

# %%
import numpy as np

# %% [markdown]
# If you now insert your cursor after `np` and press **Period**(`.`), you will see the list of available completions within the `np` module. Completions can be opened again by using **Ctrl+Space**.

# %%
np

# %% [markdown]
# If you type an open parenthesis after any function or class in the module, you will see a pop-up of its documentation string:

# %%
np.ndarray

# %% [markdown]
# The documentation can be opened again using **Ctrl+Shift+Space** or you can view the documentation for method by mouse hovering over the method name.
#
# When hovering over the method name the `Open in tab` link will open the documentation in a persistent pane. The `View source` link will navigate to the source code for the method.

# %% [markdown]
# ### Integration with Drive
#
# Colaboratory is integrated with Google Drive. It allows you to share, comment, and collaborate on the same document with multiple people:
#
# * The **SHARE** button (top-right of the toolbar) allows you to share the notebook and control permissions set on it.
#
# * **File->Make a Copy** creates a copy of the notebook in Drive.
#
# * **File->Save** saves the File to Drive. **File->Save and checkpoint** pins the version so it doesn't get deleted from the revision history.
#
# * **File->Revision history** shows the notebook's revision history.

# %% [markdown]
# ### Commenting on a cell
# You can comment on a Colaboratory notebook like you would on a Google Document. Comments are attached to cells, and are displayed next to the cell they refer to. If you have **comment-only** permissions, you will see a comment button on the top right of the cell when you hover over it.
#
# If you have edit or comment permissions you can comment on a cell in one of three ways:
#
# 1. Select a cell and click the comment button in the toolbar above the top-right corner of the cell.
# 1. Right click a text cell and select **Add a comment** from the context menu.
# 3. Use the shortcut **Ctrl+Shift+M** to add a comment to the currently selected cell.
#
# You can resolve and reply to comments, and you can target comments to specific collaborators by typing *+[email address]* (e.g., `+user@domain.com`). Addressed collaborators will be emailed.
#
# The Comment button in the top-right corner of the page shows all comments attached to the notebook.

# %% [markdown]
# ## Working with files

# %% [markdown]
# ## Understanding Kernel and Kernel State

# %% [markdown]
# ## Let's Debug: Apply the Help Hierarchy

# %% [markdown]
# ## Things to Try

# %% [markdown]
# ## What's Next?
