# %% [markdown]
# <a href="https://colab.research.google.com/github/dataprogpy/code-samples/blob/main/starter_files/02_intro_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1: Why Learn Python for Data?
#
# Welcome to your first hands-on session with Python for data analysis! In this notebook, we'll explore the foundational concepts of Python that will empower you to turn data into actionable insights.

# %% [markdown]
# ## 1.1 The Goal: From Data to Decisions
#
# In today's business world, data is the cornerstone of insight and strategy. From understanding customer behavior and market trends to optimizing operations and forecasting finances, organizations are awash in information. The critical challenge—and opportunity—lies in transforming this raw data into clear insights that drive smarter, more effective business decisions.
#
# While tools like spreadsheets are invaluable, they often encounter limitations when faced with modern data challenges:
#
# * **Scale**: Analyzing datasets that grow from thousands to millions (or even billions!) of records can become slow or unmanageable.
# * **Complexity**: Performing sophisticated statistical analyses, applying machine learning models, or running complex simulations often requires more power and flexibility.
# * **Repetition**: Manually repeating the same data cleaning, analysis, or reporting process every week or month is time-consuming and prone to errors.
# * **Integration**: Combining and reconciling data from various sources (databases, APIs, different file types) can be a cumbersome manual undertaking.
#
# This is where learning to program, specifically with Python, becomes a game-changer. Programming allows you to systematically instruct the computer to:
#
# * Handle large and complex datasets efficiently.
# * Implement sophisticated analytical techniques reproducibly.
# * Automate repetitive workflows, freeing up your time for strategic thinking.
# * Integrate diverse data sources more seamlessly.
#
# Our goal in this course isn't just about writing code; it's about significantly enhancing your analytical toolkit. You'll gain the ability to tackle more complex problems, derive deeper insights, and ultimately make more robust, data-informed decisions in your professional roles.

# %% [markdown]
# ## 1.2 Our Approach: Modeling & Automation
#
# Learning any new language, including a programming language, involves understanding its vocabulary and grammar (syntax). While syntax is essential, it's more effective to grasp *why* these rules exist and *what* they help us achieve.
#
# In this course, we'll frame our Python learning around two core concepts directly relevant to data analysis for MBA students:
#
# 1.  **Modeling Information**: How do we represent real-world entities—like customers, products, transactions, financial reports, or survey responses—in a way that a computer can understand and process? We'll learn how Python's fundamental components (such as data types and structures) act as building blocks to create flexible and accurate models of the information we care about.
# 2.  **Automating Tasks**: How do we leverage the computer to perform the heavy lifting? This includes processing thousands of data entries, applying calculations consistently, or making decisions based on specific criteria. We'll explore Python's control structures (like loops and conditional statements) that allow us to define and automate these workflows.
#
# Thinking in terms of **Modeling** and **Automation** will provide a practical purpose to the Python features you learn. For example, variables aren't just abstract names; they label parts of our information model. Lists aren't just collections; they structure data within our model. And loops aren't just syntax; they are powerful engines for automation.

# %% [markdown]
# ## 1.3 Python: Our Tool of Choice
#
# Why Python? Among the many programming languages available, Python has risen to prominence in the world of data science, analytics, and machine learning for several compelling reasons:
#
# * **Vast Data Science Ecosystem**: Python boasts an unparalleled collection of specialized **libraries** (pre-built code packages) tailored for data tasks. Throughout this course, we'll work with powerful libraries such as:
#     * **Polars**: For high-performance data manipulation and analysis (especially with large datasets).
#     * **Altair**: For creating insightful and declarative data visualizations.
#     * **(Later in your studies) Scikit-learn**: The industry standard for machine learning.
#     Learning Python unlocks access to these cutting-edge tools.
# * **Readability and Ease of Learning**: Python's syntax is often described as clean, intuitive, and resembling plain English. This generally makes it more approachable for beginners compared to other languages, allowing you to focus more on analytical concepts and less on complex programming rules.
# * **Large and Active Community**: Python's popularity translates into a massive global community of users. This means abundant learning resources (tutorials, forums, articles, courses), readily available help when you encounter challenges, and a high demand for Python skills in the job market.
#
# Learning Python will provide you with a versatile, powerful, and highly relevant foundation for anyone working with data in a business context.

# %%
# This is a code cell.
# Click the "play" button to the left of this cell, or press Shift+Enter to run it.
print("Hello, Data Scientists! Welcome to Python.")

# %% [markdown]
# # Section 2: Modeling Information - The Basic Building Blocks
#
# To analyze data, we first need a way to represent that data in our code. In this section, we'll start with the simplest forms of information – basic facts and values – and learn how Python understands them. This is the first step towards **Modeling Information**.

# %% [markdown]
# ## 2.1 Literals & Core Data Types: Raw Information
#
# The most basic way to represent information in Python is by using **literals**. Literals are fixed values written directly into your code. Think of these as the raw facts or pieces of data you might start with.
#
# Each literal belongs to a fundamental **data type**. The data type tells Python what kind of information it is and what operations are allowed with it. Here are the core data types we'll use constantly:
#
# * **Strings (`str`)**: Used for textual data. Enclose text in *either* single quotes (`'...'`) or double quotes (`"..."`).
#     * Example: `"Midtown Office"`, `'Project Alpha'`
# * **Integers (`int`)**: Used for whole numbers (positive, negative, or zero).
#     * Example: `255`, `-100`, `2024`
# * **Floats (`float`)**: Used for numbers that have a decimal component (floating-point numbers).
#     * Example: `15750.25`, `0.05`, `3.14159` (Note: Even `2.0` is a float, not an int)
# * **Booleans (`bool`)**: Represent logical `True` or `False` values. These are crucial for making decisions in your code. Note the capitalization.
#     * Example: `True`, `False`
# * **The `None` Type (`NoneType`)**: A special type representing the intentional absence of a value. It's often used as a placeholder or to indicate that data is missing or not applicable. There's only one `None` value.
#     * Example: `None`

# %%
# Examples of literals
print("This is a string.")
print('So is this, using single quotes.')
print("Company: FutureCorp")

print(42) # An integer
print(-150) # A negative integer

print(3.14159) # A float
print(2500.0)  # This is also a float because of the .0

print(True)  # A boolean
print(False) # Another boolean

print(None)  # The None value

# %% [markdown]
# **Checking the Data Type with `type()`**
#
# Python provides a built-in function called `type()` that lets you ask what data type a specific value (or a variable holding a value) is. This is very useful for understanding your data and for debugging.
#
# **Quick Tip for Debugging**: Remember `print()` and `type()`!
# * Use `print()` to display the values of your variables at different stages of your code.
# * Use `type()` to check if a variable is holding the kind of data you expect.
# These are your first go-to tools for troubleshooting!

# %%
# Using type() to check the data type of our literals
print( type("Hello, Python for MBAs!") )
print( type(123) )
print( type(98.6) )
print( type(True) )
print( type(None) )

# What about a number like 7.0?
print( type(7.0) )

# %% [markdown]
# ## 2.2 Expressions & Operators: Combining and Comparing Information
#
# Rarely do we work with just single literal values. We usually need to combine, compare, or perform calculations on them. We do this using **expressions** and **operators**.
#
# * An **expression** is a piece of code that Python evaluates to produce a value (e.g., `5 + 3` is an expression that evaluates to `8`).
# * **Operators** are the special symbols that perform the actions (like `+`, `-`, `*`, `/`).
#
# Here are common types of operators:
#
# **Arithmetic Operators** (primarily for `int` and `float`):
# * `+` : Addition
# * `-` : Subtraction
# * `*` : Multiplication
# * `/` : True Division (result is *always* a float, e.g., `10 / 4` is `2.5`)
# * `//`: Floor Division (discards the decimal/remainder, e.g., `10 // 4` is `2`)
# * `%` : Modulo (gives the remainder, e.g., `10 % 4` is `2`)
# * `**`: Exponentiation (e.g., `10 ** 2` is `100`)
#
# **Comparison Operators** (these *always* result in a `True` or `False` boolean value):
# * `==`: Equal to
# * `!=`: Not equal to
# * `<` : Less than
# * `>` : Greater than
# * `<=`: Less than or equal to
# * `>=`: Greater than or equal to
#     *(These also work for comparing strings alphabetically, e.g., `"apple" < "banana"` is `True`)*
#
# **Logical Operators** (for combining `True`/`False` values):
# * `and`: `True` if both sides are `True` (e.g., `True and True` is `True`)
# * `or` : `True` if at least one side is `True` (e.g., `True or False` is `True`)
# * `not`: Reverses the boolean value (e.g., `not True` is `False`)

# %%
# Arithmetic Operator Examples
revenue = 50000
cost_of_goods = 30000
units_sold = 1000
marketing_spend = 5000

profit = revenue - cost_of_goods - marketing_spend
print(f"Profit: {profit}")

price_per_unit = revenue / units_sold
print(f"Price per unit: {price_per_unit}")

# What if we want to know how many full packs of 12 we can make from 150 items?
items = 150
pack_size = 12
full_packs = items // pack_size
remaining_items = items % pack_size
print(f"Full packs of {pack_size}: {full_packs}, Remaining items: {remaining_items}")

# Growth over 2 years at 10% annually (1.1^2)
initial_investment = 1000
growth_factor = 1.1 ** 2
future_value = initial_investment * growth_factor
print(f"Future value: {future_value}")

# %%
# Comparison Operator Examples
min_profitable_sales = 40000
actual_sales_q1 = 45000
actual_sales_q2 = 38000

is_q1_profitable = actual_sales_q1 > min_profitable_sales
print(f"Were Q1 sales profitable? {is_q1_profitable}")
print(f"Type of is_q1_profitable: {type(is_q1_profitable)}") # It's a boolean!

is_q2_meeting_target = actual_sales_q2 >= min_profitable_sales
print(f"Did Q2 sales meet the minimum target? {is_q2_meeting_target}")

are_sales_consistent = actual_sales_q1 == actual_sales_q2
print(f"Were Q1 and Q2 sales identical? {are_sales_consistent}")

# %%
# Logical Operator Examples
has_high_revenue = actual_sales_q1 > 42000  # Let's say this is True (45000 > 42000)
has_low_costs = cost_of_goods < 32000    # Let's say this is True (30000 < 32000)
is_new_product = False

# Eligible for bonus if high revenue AND low costs
eligible_for_bonus = has_high_revenue and has_low_costs
print(f"Eligible for performance bonus? {eligible_for_bonus}")

# Flag for review if it's a new product OR if not meeting sales targets
flag_for_review = is_new_product or (not is_q2_meeting_target) # (not False is True)
print(f"Flag product for review? {flag_for_review}")

# Using 'not'
print(f"Is Q2 NOT meeting target? {not is_q2_meeting_target}")

# %% [markdown]
# ## 2.3 Variables: Naming Information for Reuse
#
# Hardcoding literal values everywhere in your analysis makes your code hard to read, understand, and maintain. If a value (like a tax rate or a sales target) needs to change, you'd have to find and replace it in many places!
#
# More importantly for our "Modeling Information" approach, we want to give meaningful names to the different pieces of our information model. We achieve this using **variables**.
#
# * **Assignment (`=`)**: You create a variable and assign it a value using the single equals sign (`=`).
#     `variable_name = value`
# * **Analogy**: Think of a variable as a label or a tag pointing to a value stored in the computer's memory. You use the label (the variable name) to refer to that value.
#
# Once you assign a value to a variable, you can use the variable name in expressions, print it, or use it anywhere you would use the value itself.

# %%
# Modeling details for a product
product_id = "PROD007"         # Assigning a string
product_name = "Wireless Mouse X2" # Assigning another string
units_in_stock = 150            # Assigning an int
unit_price = 29.99              # Assigning a float
is_active_product = True        # Assigning a bool

# Using the variables
print(product_name)
print(f"Price per unit: {unit_price}")

# Variables can be used in expressions
total_stock_value = units_in_stock * unit_price
print(f"Total stock value for {product_name} (ID: {product_id}): ${total_stock_value}")

# Variable values can be updated (re-assignment)
print(f"Units in stock before sale: {units_in_stock}")
units_sold_today = 25
units_in_stock = units_in_stock - units_sold_today # Update the variable
print(f"Units in stock after selling {units_sold_today}: {units_in_stock}")

# %% [markdown]
# **Variable Naming Conventions (Python Best Practice - PEP 8)**:
#
# * **Use `snake_case`**: All lowercase letters, with words separated by underscores (e.g., `hourly_rate`, `customer_first_name`, `net_profit_margin`). This is the standard convention in the Python community and makes code more readable.
# * **Be Descriptive**: Choose names that clearly indicate the variable's purpose (e.g., `average_customer_rating` is much better than `acr` or `rating_val`).
# * **Start with a letter or underscore**: Variable names must start with a letter (a-z, A-Z) or an underscore (`_`). They can then be followed by letters, numbers (0-9), or underscores.
# * **Case-Sensitive**: `my_variable` is different from `My_Variable`.
# * **Avoid Python Keywords**: Do not use Python's reserved keywords (like `if`, `for`, `while`, `True`, `None`, `def`, `class`, etc.) as variable names.
#
# **Comments (`#`): Explaining Your Code**
#
# As you assign variables and write logic, it's crucial to add **comments** to your code. In Python, anything on a line after the hash symbol (`#`) is a comment and is ignored by the Python interpreter.
#
# Comments don't affect how your code runs, but they are vital for:
# * Explaining the *purpose* or *why* behind a piece of code.
# * Making your code understandable to others (and to your future self!).
# * Temporarily "turning off" lines of code during debugging (known as "commenting out").

# %%
# Good variable names and comments example

# --- Financial Configuration ---
corporate_tax_rate = 0.21          # Current federal corporate tax rate
risk_free_rate = 0.02              # Assumed risk-free rate for financial models
fiscal_year_start_month = "July"   # Company's fiscal year starting month

# --- Customer Metrics ---
target_customer_satisfaction_score = 4.5 # On a 5-point scale
new_customer_acquisition_cost = 150.75   # Average cost in USD

# Example of a calculation using these variables
projected_revenue = 1000000
estimated_profit_before_tax = projected_revenue * 0.30 # Assuming a 30% gross margin
estimated_tax = estimated_profit_before_tax * corporate_tax_rate
estimated_profit_after_tax = estimated_profit_before_tax - estimated_tax

print(f"Projected Revenue: ${projected_revenue:,.2f}") # :,.2f adds comma separators and 2 decimal places
print(f"Estimated Profit After Tax: ${estimated_profit_after_tax:,.2f}")

# Example of "commenting out" a line:
# print("This line will not run because it is commented out.")

# %% [markdown]
# ## 2.4 Working with Text (`str`): A Closer Look
#
# Text data (strings, or `str` in Python) is fundamental in business. You'll encounter it everywhere: customer names, product descriptions, addresses, survey responses, log files, financial report narratives, and much more. Python's strings come with powerful built-in capabilities for manipulation, which is often a key part of data cleaning and preparation.
#
# **Combining Strings (Concatenation)**:
# You can combine strings using the `+` operator. Remember to add spaces manually if needed!
#
# **Common String Methods**:
# Strings are objects in Python, and objects have built-in functions called **methods** that perform actions related to the object. You call a method using *dot notation*: `your_string_variable.method_name(arguments)`.
#
# Here are some essential string methods for data cleaning and manipulation:
# * `.lower()`: Returns a *new* string with all characters converted to lowercase.
# * `.upper()`: Returns a *new* string with all characters converted to uppercase.
# * `.strip()`: Returns a *new* string with leading and trailing whitespace (spaces, tabs, newlines) removed. This is invaluable for cleaning user input or data from files!
# * `.replace(old, new)`: Returns a *new* string where all occurrences of the `old` substring are replaced with the `new` substring.
# * `.startswith(prefix)`: Returns `True` if the string starts with the `prefix`, `False` otherwise.
# * `.endswith(suffix)`: Returns `True` if the string ends with the `suffix`, `False` otherwise.
# * `.split(separator)`: Returns a *list* of substrings that were separated by the `separator`. If no separator is given, it splits by whitespace.
#
# **Important Note on Immutability**: Strings in Python are **immutable**. This means that string methods *do not change the original string*. Instead, they return a *new* string with the modifications. If you want to keep the change, you must assign the result back to a variable (it can be the same variable or a new one).

# %%
# String Concatenation
first_name = "Jane"
last_name = "Doe"
role = "Analyst"

full_name = first_name + " " + last_name # Don't forget the space!
print(f"Full Name: {full_name}")

# String Methods
messy_department_code = "  FINANCE_DEPT_US\n" # Has extra spaces and a newline
print(f"Original Department Code: '{messy_department_code}'")

# Clean it up
clean_department_code = messy_department_code.strip().upper()
print(f"Cleaned Department Code: '{clean_department_code}'")

# Using replace
report_title = "Quarterly Report - Q2 2024"
updated_report_title = report_title.replace("2024", "2025")
print(f"Original Title: {report_title}")
print(f"Updated Title: {updated_report_title}") # Original report_title is unchanged

# Using startswith and endswith
file_name = "SalesData_Final_Report.xlsx"
if file_name.startswith("SalesData") and file_name.endswith(".xlsx"):
    print(f"'{file_name}' looks like a valid sales report Excel file.")
else:
    print(f"'{file_name}' might not be the correct file type or naming convention.")

# Using split
tags_string = "marketing, finance, strategy, operations"
tags_list = tags_string.split(", ") # Split by comma followed by a space
print(f"Tags as a list: {tags_list}")
print(f"The first tag is: {tags_list[0]}") # We'll learn about lists soon!

# %% [markdown]
# **F-Strings (Formatted String Literals): The Best Way to Combine Strings and Variables**
#
# We've already used f-strings in many of our `print()` examples! They provide the clearest, most readable, and most convenient way to create strings that include the values of variables.
#
# **How to use f-strings**:
# 1.  Start the string with the letter `f` or `F` immediately before the opening quote (`f"..."` or `f'...'`).
# 2.  Inside the string, place variable names or even simple Python expressions directly within curly braces `{}`. Python will replace the braces and their contents with the current value of the variable or the result of the expression.
#
# You can also control the formatting of numbers within f-strings. For example, `:.2f` is often used to format a float to display exactly two decimal places (very useful for currency).

# %%
# F-String Examples
product_id = "SRV003"
product_name = "Cloud Storage Subscription"
monthly_cost = 49.99
users = 150
discount_percentage = 10 # As a whole number

# Basic f-string usage
output_message = f"Product: {product_name} (ID: {product_id}) costs ${monthly_cost} per month."
print(output_message)

# F-strings with calculations
total_annual_cost = monthly_cost * 12
print(f"The total annual cost for {product_name} is ${total_annual_cost:.2f}.") # Formatted to 2 decimal places

discounted_monthly_cost = monthly_cost * (1 - discount_percentage / 100)
print(f"With a {discount_percentage}% discount, the monthly cost is ${discounted_monthly_cost:.2f}.")

# You can even include more complex expressions or function calls (though keep it readable)
active_status_text = "Active" if is_active_product else "Inactive" # This is a conditional expression
print(f"The product '{product_name}' is currently {active_status_text.upper()}.") # Method call inside f-string

# %% [markdown]
# # Section 3: Modeling Structures - Organizing Related Information
#
# We've learned how to represent basic pieces of information (like text, numbers, and booleans) and assign them to variables. However, data in the real world rarely exists in isolation. Information is usually:
# * Part of a collection (e.g., a list of all sales figures for a quarter).
# * Grouped as a record (e.g., all details for a single customer: name, ID, email).
# * Requiring specialized tools (e.g., working with dates and times).
#
# This section introduces Python's fundamental **data structures** for organizing related information. We'll also learn how to access external code tools using `import`.

# %% [markdown]
# ## 3.1 Importing Modules: Accessing More Tools
#
# Python itself provides the basic building blocks, but much of its power, especially for data analysis, comes from **modules** and **packages** (often collectively called **libraries**). These are collections of pre-written code, created by other developers (or by Python's core team), that provide specialized functions, data types, and capabilities.
#
# Think of Python's built-in features as your standard workshop tools. Modules are like specialized toolsets you can bring into your workshop when needed:
# * A set for advanced mathematical operations.
# * A set for creating charts and visualizations.
# * A set for accessing web data.
# * Importantly for us, tools for handling dates and times, or performing large-scale data manipulation (like the Polars library we'll see later).
#
# To use the tools (functions, classes, etc.) from a module or library, you must first **`import`** it into your current Colab session (or Python script).
#
# **How to Import:**
#
# 1.  **`import module_name`**: This brings the entire module into your session's memory. To use something *from* the module, you typically prefix it with the module's name followed by a dot (`.`).
#     * Example: `math.sqrt(25)` would use the `sqrt` function from the `math` module.
#
# 2.  **`import module_name as alias`**: This is extremely common, especially for modules with long names or those that have widely accepted standard abbreviations. It imports the module but assigns it a shorter, convenient nickname (**alias**) that you use instead of the full name. This makes your code less verbose and often follows community conventions.
#     * Example: `import datetime as dt` (common for the `datetime` module).
#     * Example: `import polars as pl` (which we will use extensively later).
#
# **Convention for Imports**:
# By strong convention, all `import` statements are usually placed at the **very top** of a Jupyter Notebook or Python script. This clearly declares all the external tools your code relies on from the outset.

# %%
# Example of importing and using a module
# The 'datetime' module provides tools for working with dates and times.
# We import it using a common alias 'dt'.

import datetime as dt

# Get today's date
todays_date = dt.date.today()
print(f"Today's date is: {todays_date}")

# Date objects have attributes you can access
print(f"The current year is: {todays_date.year}")
print(f"The current month is: {todays_date.month}")
print(f"The current day is: {todays_date.day}")

# We can also create specific date objects
specific_date = dt.date(2025, 1, 31) # Year, Month, Day
print(f"A specific date: {specific_date}")
print(f"The weekday of {specific_date} is: {specific_date.weekday()} (Monday=0, Sunday=6)")

# Get the current date and time
current_timestamp = dt.datetime.now()
print(f"Current date and time: {current_timestamp}")
print(f"Just the hour: {current_timestamp.hour}")
print(f"Just the minute: {current_timestamp.minute}")

# %% [markdown]
# ## 3.2 Lists (`list`): Ordered, Changeable Sequences
#
# **Modeling Motivation**: How do you represent a collection of related items where the *order is important* and the items might need to change?
# * A sequence of steps in a marketing campaign.
# * Monthly revenue figures recorded in chronological order.
# * A list of client names, perhaps in the order they were acquired.
# * The columns you want to select from a dataset.
#
# Python's solution is the **list**. A list is an **ordered sequence** of items.
# * Items can be of any data type (though often they are homogeneous, meaning all the same type, especially in data analysis).
# * The order in which you add items is preserved.
# * Lists are **mutable**, meaning you can change their contents after they are created (add, remove, or modify items).
#
# **Syntax**: Create lists using square brackets `[]`, with items separated by commas.

# %%
# A list of region names (strings)
regions = ["North", "South", "East", "West", "Central"]
print(f"Regions: {regions}")

# A list of quarterly sales targets (floats)
quarterly_sales_targets = [150000.00, 182000.50, 141000.75, 195000.20]
print(f"Quarterly Sales Targets: {quarterly_sales_targets}")

# A list can technically mix data types (but use with caution for data analysis)
# For data analysis, lists (which often become columns) usually contain the same type of data.
mixed_info = ["Product Launch Plan", 2025, 15000.00, True]
print(f"Mixed Info List: {mixed_info}")

# An empty list, ready to be filled later
pending_tasks = []
print(f"Pending Tasks (initially): {pending_tasks}")

# %% [markdown]
# **Accessing Items by Index (Position)**:
# Because lists are ordered, you retrieve items using their numerical position, called an **index**.
# * **Crucially, Python indexing starts from 0!** The first item is at index `0`, the second at index `1`, and so on.
# * You can also use **negative indexing**: `-1` refers to the last item, `-2` to the second-to-last, etc.
#
# Trying to access an index outside the list's range (e.g., index `10` in a list of 5 items) will cause an `IndexError`.

# %%
# Accessing items from our 'regions' list: ["North", "South", "East", "West", "Central"]
first_region = regions[0]         # Index 0 is the FIRST item
second_region = regions[1]        # Index 1 is the SECOND item

print(f"First region: {first_region}")
print(f"Second region: {second_region}")

last_region = regions[-1]         # Index -1 is the LAST item
second_to_last_region = regions[-2] # Index -2 is the second-to-last

print(f"Last region: {last_region}")
print(f"Second-to-last region: {second_to_last_region}")

# Let's try to access an out-of-range index (this will produce an error)
# print(regions[10]) # Uncomment this line to see the IndexError

# %% [markdown]
# **Slicing (Getting Sub-Lists)**:
# You can extract a portion (a "slice" or sub-list) of a list using the syntax `my_list[start:stop]`.
# * The `start` index is the position of the first item you want to include.
# * The `stop` index is the position of the first item you *do not* want to include (i.e., slicing goes up to, but does not include, the `stop` index).
# * If `start` is omitted, slicing starts from the beginning of the list (`my_list[:stop]`).
# * If `stop` is omitted, slicing goes to the end of the list (`my_list[start:]`).
# * You can also use a `step`: `my_list[start:stop:step]`.

# %%
# Slicing our 'regions' list: ["North", "South", "East", "West", "Central"]

# Get 'South' and 'East' (index 1 up to, but not including, index 3)
middle_regions = regions[1:3]
print(f"Middle regions (index 1 to 3 exclusive): {middle_regions}")

# Get from the beginning up to index 2 (exclusive)
first_two_regions = regions[:2]
print(f"First two regions (up to index 2 exclusive): {first_two_regions}")

# Get from index 2 to the end
regions_from_east_onwards = regions[2:]
print(f"Regions from 'East' onwards (index 2 to end): {regions_from_east_onwards}")

# Get every other region, starting from the first
every_other_region = regions[::2] # Start defaults to 0, Stop defaults to end
print(f"Every other region: {every_other_region}")

# Get a copy of the entire list
all_regions_copy = regions[:]
print(f"A copy of all regions: {all_regions_copy}")

# %% [markdown]
# **Mutability (Lists are Changeable)**:
# Lists are **mutable**, meaning you can change their contents after they are created.
# * **Change an item**: Use index assignment (`my_list[index] = new_value`).
# * **Add an item to the end**: Use the `.append()` method.
# * There are other methods like `.insert()` to add at a specific position, `.remove()` to delete an item by value, and `del my_list[index]` to delete by index.
#
# **Getting the Length of a List**:
# Use the built-in `len()` function to find out how many items are in a list.

# %%
# Modifying lists
print(f"Original Quarterly Sales Targets: {quarterly_sales_targets}")

# Let's say Q1 target was revised
quarterly_sales_targets[0] = 160000.00 # Change item at index 0
print(f"Updated Q1 Target: {quarterly_sales_targets}")

# Add a new sales target for Q5 (e.g., for a special period)
quarterly_sales_targets.append(210000.00)
print(f"Targets after appending Q5: {quarterly_sales_targets}")

# Add a task to our 'pending_tasks' list
pending_tasks.append("Draft Q3 financial report")
pending_tasks.append("Analyze customer feedback")
pending_tasks.append("Prepare slides for stakeholder meeting")
print(f"Pending Tasks: {pending_tasks}")

# Get the number of tasks
number_of_tasks = len(pending_tasks)
print(f"Number of pending tasks: {number_of_tasks}")

# Get the number of regions
number_of_regions = len(regions)
print(f"Number of regions: {number_of_regions}")

# %% [markdown]
# ## 3.3 Tuples (`tuple`): Ordered, Unchangeable Records
#
# **Modeling Motivation**: What if you want to group related pieces of information about a *single thing*, where the order matters, but the structure itself *should not change* after it's created?
# * An (X, Y) coordinate point on a map or chart.
# * An RGB color value: `(red_value, green_value, blue_value)`.
# * A basic, fixed record for an employee: `(employee_id, name, hire_date)`.
# * A specific version number `(major, minor, patch)`.
#
# Python provides **tuples** for this. A tuple is also an **ordered sequence**, much like a list.
#
# **Key Difference**: Tuples are **immutable**. Once created, you *cannot* change, add, or remove elements. This immutability signals that the tuple represents a fixed record or structure.
#
# **Syntax**: Usually created using parentheses `()`, with items separated by commas.
# (Parentheses are often optional if the context is clear, but it's good practice to use them for readability).
# * A tuple with a single item *must* have a trailing comma: `(item,)`.

# %%
# Tuples examples

# Tuple representing (latitude, longitude) coordinates for a store
store_location_A = (40.7128, -74.0060) # (Latitude, Longitude) for NYC
store_location_B = (34.0522, -118.2437) # for LA
print(f"Store A Coordinates: {store_location_A}")

# Tuple representing a fixed financial period (Year, Quarter)
fiscal_period = (2024, "Q3")
print(f"Fiscal Period: {fiscal_period}")

# Tuple representing a product version
software_version = (2, 1, 5) # Major, Minor, Patch
print(f"Software Version: {software_version}")

# A tuple requires a comma even for a single item!
# This distinguishes it from just a value in parentheses (which would be for operator precedence).
single_config_setting = ("localhost",)
print(f"Single config setting (tuple): {single_config_setting}")
print(f"Type of single_config_setting: {type(single_config_setting)}")

# Compare to this:
not_a_tuple = ("localhost") # This is just a string
print(f"Not a tuple (string): {not_a_tuple}")
print(f"Type of not_a_tuple: {type(not_a_tuple)}")


# Empty tuple
empty_record = ()
print(f"Empty record: {empty_record}")

# %% [markdown]
# **Accessing Items by Index (Same as Lists)**:
# You access items in a tuple using their zero-based index, just like lists.
#
# **Immutability (The Defining Feature)**:
# This is where tuples differ critically from lists. Once a tuple is created, its contents cannot be altered.

# %%
# Accessing items in a tuple
print(f"Store A Latitude: {store_location_A[0]}")
print(f"Store A Longitude: {store_location_A[1]}")

print(f"Software Major Version: {software_version[0]}")

# --- Attempting to change a tuple will cause an ERROR ---
# If you uncomment and run the following lines, you'll get a TypeError.

# store_location_A[0] = 40.7129  # This will raise a TypeError: 'tuple' object does not support item assignment
# software_version.append(3)     # This will raise an AttributeError: 'tuple' object has no attribute 'append'

# print("This line will not be reached if the errors above are uncommented.")

# %% [markdown]
# **Why Use Tuples?**
#
# 1.  **Data Integrity**: They signal that this group of items represents a fixed record or structure that shouldn't be accidentally altered. If you have a collection of items that should logically stay together and not change, a tuple is a good choice.
# 2.  **Performance (Minor)**: Tuples can be slightly more memory-efficient and sometimes faster to process than lists for certain operations, though this is usually not a primary concern for basic usage.
# 3.  **Dictionary Keys**: Because they are immutable, tuples can be used as keys in dictionaries (which we'll see next). Lists, being mutable, cannot be dictionary keys.
#
# **Common Use Case: List of Tuples**
# A very frequent and useful pattern for representing simple tables of data (like rows from a spreadsheet or database) is a **list of tuples**. Each tuple in the list represents one row or record, and its elements represent the fields of that record.

# %%
# List of tuples: (Product ID, Product Name, Unit Price, Quantity in Stock)
inventory = [
    ("P1001", "Laptop Pro 15", 1299.99, 50),
    ("P1002", "Wireless Mouse XG", 24.50, 120),
    ("P1003", "External SSD 1TB", 175.00, 75),
    ("A2005", "Office Software Suite", 199.00, 200) # Another product
]
print("Current Inventory (List of Tuples):")
print(inventory)

# Access the second product record (which is a tuple)
product2_record = inventory[1] # inventory[1] is the tuple ("P1002", "Wireless Mouse XG", ...)
print(f"\nProduct 2 Record: {product2_record}")

# Access the unit price of the second product
# First, get the tuple for the second product (inventory[1])
# Then, get the price from that tuple (index 2)
product2_price = inventory[1][2]
print(f"Product 2 Unit Price: ${product2_price}")

# Access the name of the third product
product3_name = inventory[2][1]
print(f"Product 3 Name: {product3_name}")

# We can easily add another record (tuple) to our list of inventory
new_product_record = ("C3010", "Webcam HD Pro", 65.00, 90)
inventory.append(new_product_record) # Appending to the LIST, not the tuples themselves
print("\nInventory after adding a new product:")
print(inventory)

# %% [markdown]
# ## 3.4 Dictionaries (`dict`): Labeled Information (Key-Value Pairs)
#
# **Modeling Motivation**: Accessing items by numerical position (index) like in lists and tuples isn't always the most intuitive or practical way to retrieve information.
# * How would you model configuration settings where you want to look up the 'server_ip_address' or 'default_timeout_seconds'?
# * How would you represent a product where you want to directly access its 'price' or 'brand_name' or 'sku' using those specific names?
#
# Python's **dictionaries** (or `dict`) are perfect for this. A dictionary stores a collection of **key-value pairs**.
# * Each unique **key** is associated with a specific **value**.
# * Think of it like a real-world dictionary where the word (key) points to its definition (value), or like a labeled filing cabinet.
# * Keys must be unique within a dictionary.
# * Keys must be of an immutable type (e.g., strings, numbers, or tuples are common keys; lists cannot be keys).
# * Values can be of any data type (including other lists or dictionaries!).
# * Dictionaries are **mutable**: you can add, remove, or change key-value pairs after creation.
# * In modern Python (3.7+), dictionaries also remember the order in which items were inserted.
#
# **Syntax**: Dictionaries are created using curly braces `{}`, containing `key: value` pairs separated by commas.

# %%
# Dictionary modeling application configuration settings
app_config = {
    "server_ip": "192.168.1.100",
    "port": 8080,
    "api_version": "v2.1",
    "default_timeout_seconds": 60,
    "active_feature_flags": ["new_dashboard", "beta_analytics_panel"], # Value can be a list!
    "retry_attempts": 3
}
print(f"Application Configuration: {app_config}")

# Dictionary modeling a customer record
customer_profile = {
    "customer_id": "CUST-00789",
    "name": "Alice Wonderland",
    "email": "alice.w@example.com",
    "loyalty_tier": "Gold",
    "total_spend_usd": 1250.75,
    "is_subscribed_to_newsletter": True
}
print(f"\nCustomer Profile: {customer_profile}")

# Empty dictionary, can be filled later
project_details = {}
print(f"\nEmpty Project Details: {project_details}")

# %% [markdown]
# **Accessing Values by Key**:
# You don't use numerical indices with dictionaries. Instead, you use the **key** inside square brackets `[]` to get its associated value.
#
# Attempting to access a key that doesn't exist in the dictionary will raise a `KeyError`.
# A safer way to access keys that might be missing is using the `.get()` method: `my_dict.get('some_key', default_value_if_missing)`.

# %%
# Accessing values from our dictionaries

server_address = app_config["server_ip"]
print(f"Server IP from config: {server_address}")

customer_name = customer_profile["name"]
customer_email = customer_profile["email"]
print(f"Customer: {customer_name}, Email: {customer_email}")

# What happens if we try to access a key that doesn't exist?
# print(app_config["admin_username"]) # Uncomment to see a KeyError

# Safer access using .get()
# .get() returns None if the key is not found, or you can provide a default value.
admin_username = app_config.get("admin_username")
print(f"Admin Username (using .get()): {admin_username}") # Will be None

admin_username_with_default = app_config.get("admin_username", "default_admin")
print(f"Admin Username (with default): {admin_username_with_default}")

# Accessing the list of feature flags
active_flags = app_config["active_feature_flags"]
print(f"Active feature flags: {active_flags}")
print(f"The first active feature flag is: {active_flags[0]}") # This is a list, so we use list indexing

# %% [markdown]
# **Mutability (Dictionaries are Changeable)**:
# Dictionaries are **mutable**. You can:
# * Add new key-value pairs.
# * Change the value associated with an existing key.
# * Remove key-value pairs (e.g., using `del my_dict['key_to_delete']` or the `.pop()` method).

# %%
# Modifying dictionaries
print(f"Original Customer Profile: {customer_profile}")

# Update the customer's email and loyalty tier
customer_profile["email"] = "alice.wonderland@newdomain.com" # Updates existing key
customer_profile["loyalty_tier"] = "Platinum"             # Updates existing key
print(f"\nUpdated Customer Profile (email, tier): {customer_profile}")

# Add new information: a phone number
customer_profile["phone_number"] = "555-123-4567" # Adds a new key-value pair
print(f"\nCustomer Profile after adding phone: {customer_profile}")

# Add details to the 'project_details' dictionary
project_details["project_name"] = "Q4 Market Expansion Analysis"
project_details["due_date"] = dt.date(2025, 10, 15) # Value can be a date object!
project_details["status"] = "In Progress"
print(f"\nUpdated Project Details: {project_details}")

# Removing a key-value pair
# Let's say we no longer want to store 'retry_attempts' in app_config
if "retry_attempts" in app_config: # Good practice to check if key exists before deleting
    del app_config["retry_attempts"]
print(f"\nApp Config after deleting 'retry_attempts': {app_config}")

# %% [markdown]
# **Key vs. Index: The Fundamental Difference in Retrieval**
#
# This is a crucial distinction:
# * **Lists/Tuples**: Are ordered sequences. You access items by their numerical **position (index)**.
#     * Example: `my_list[0]`, `my_tuple[2]`
# * **Dictionaries**: Store data as key-value pairs. You access values by their unique **label (key)**. They are conceptually unordered for access purposes (though modern Python preserves insertion order for iteration).
#     * Example: `my_dict['setting_name']`, `my_dict['customer_id']`
#
# Dictionaries are incredibly flexible and widely used for modeling objects or records where accessing information by a specific name or identifier is more natural and efficient than relying on numerical position.

# %% [markdown]
# # Section 4: Polars Teaser - Connecting to Data Analysis Tools
#
# We've spent time learning how to model information using Python's fundamental building blocks like numbers, strings, booleans, lists, tuples, and dictionaries. You might be thinking, "Okay, that's interesting, but how does creating a Python list of names or a dictionary for one product help me analyze a dataset with thousands, or even millions, of rows?"
#
# That's an excellent and very practical question!
#
# The answer is that these fundamental Python concepts are the **direct foundation** upon which powerful data analysis libraries, like **Polars** (which we'll use extensively in this course), are built and interacted with. This section provides a "teaser" or a glimpse into that connection.

# %% [markdown]
# ## 4.1 The Bridge from Python Basics to Powerful Data Libraries
#
# The Python data types (`int`, `str`, `bool`) and data structures (`list`, `dict`, `tuple`) you've just learned are not just academic exercises. They are the language you'll use to prepare data for, and interpret results from, specialized data analysis libraries.

# %% [markdown]
# ## From Python Lists/Tuples to Polars Series (One Data Column)
#
# Remember our Python lists holding sequences of items, like monthly sales figures or customer names?

# %%
# A familiar Python list of quarterly sales figures
python_quarterly_sales = [150000.50, 182000.00, 141000.75, 195000.20, 175000.00]
print(f"A Python list of sales: {python_quarterly_sales}")
print(f"Type: {type(python_quarterly_sales)}")

# %% [markdown]
# In data analysis libraries like **Polars** (or its well-known predecessor, Pandas), a single column of data in a table is typically represented by a specialized object called a **Series**.
#
# Think of a Polars **Series** as a highly optimized, super-powered version of a Python list or tuple, specifically designed for:
# * Holding data of a **single type** (e.g., all numbers, all strings, all dates). This allows for very efficient operations.
# * Performing **fast calculations** across all items in the column.
# * Handling **missing values** (`null` values) consistently and efficiently.
# * Aligning data based on labels (indices), though we won't dive deep into custom indices in this introductory part.
#
# **Conceptual Link: Python `list` or `tuple` $\approx$ Polars `Series` (One Data Column)**
#
# Let's see a quick example. First, we need to import the Polars library. The standard way to do this is `import polars as pl`.

# %%
# Import the Polars library
# If you run this cell and get an error like "ModuleNotFoundError: No module named 'polars'",
# you might need to install it. In a new code cell, you could run: !pip install polars
# Then, re-run this import cell. (Colab usually has Polars pre-installed).
import polars as pl

# Create a Polars Series from our Python list
polars_sales_series = pl.Series("quarterly_sales", python_quarterly_sales) # "quarterly_sales" is the name of the Series

print("A Polars Series:")
print(polars_sales_series)
print(f"\nType of polars_sales_series: {type(polars_sales_series)}")
print(f"Data type within the Polars Series: {polars_sales_series.dtype}")
print(f"Length of the Series: {len(polars_sales_series)}")

# Polars Series have many useful methods, e.g., calculating the sum:
print(f"Sum of sales (using Polars): {polars_sales_series.sum()}")

# %% [markdown]
# ## From Python Structures to Polars DataFrames (Tables)
#
# Now, recall how we used Python structures like a *list of tuples* or a *list of dictionaries* to represent multiple records or entities, forming a table-like structure:

# %%
# A Python list of dictionaries representing employee data
employee_data_python = [
    {"employee_id": "E101", "name": "Alice Smith", "department": "Sales", "salary": 72000},
    {"employee_id": "E102", "name": "Bob Johnson", "department": "Marketing", "salary": 68000},
    {"employee_id": "E103", "name": "Carol White", "department": "Engineering", "salary": 85000},
    {"employee_id": "E104", "name": "David Brown", "department": "Sales", "salary": 75000}
]

print("Employee data as a Python list of dictionaries:")
for record in employee_data_python:
    print(record)

# %% [markdown]
# This common Python pattern for organizing structured data directly mirrors the concept of the central object in tabular data analysis: the **DataFrame**.
#
# A Polars **DataFrame** represents a table – think of a spreadsheet with rows and columns, or a SQL table.
# * Each **column** in a Polars DataFrame is actually a Polars **Series**.
# * The entire DataFrame allows you to efficiently store, manipulate, filter, aggregate, and analyze structured, two-dimensional data.
#
# Crucially, you can often create a Polars DataFrame *directly from* these Python structures (like a list of dictionaries or a dictionary of lists)!
#
# **Conceptual Link: Python `list` of `dict`s / `dict` of `list`s / `list` of `tuple`s $\approx$ Polars `DataFrame` (A Table)**
#
# Let's see a quick example:

# %%
# import polars as pl # Already imported, but good to remember if starting fresh

# Create a Polars DataFrame directly from our list of dictionaries
employee_df = pl.DataFrame(employee_data_python)

print("Employee data as a Polars DataFrame:")
print(employee_df)

print(f"\nType of employee_df: {type(employee_df)}")
print(f"Shape of the DataFrame (rows, columns): {employee_df.shape}")
print(f"Column names: {employee_df.columns}")
print(f"Data types of each column:\n{employee_df.dtypes}")

# DataFrames have powerful methods, e.g., calculating the average salary:
print(f"\nAverage salary: {employee_df.select(pl.col('salary').mean())}")

# %% [markdown]
# ## Why This Matters for You
#
# Learning Python's core data types and structures isn't just an academic exercise to be forgotten when you start using libraries. It's essential because:
#
# 1.  **Input/Output Format**: These Python structures (lists, dictionaries, etc.) are often the format in which you'll prepare data to *load into* DataFrames or the format in which you'll get results *out of* them after an analysis.
# 2.  **Conceptual Foundation**: The way you think about accessing elements (by index like in lists, or by key like in dictionaries) and iterating over collections in basic Python provides the fundamental mental model for performing similar, but more powerful, operations in Polars and other data libraries.
# 3.  **Custom Logic & Flexibility**: While libraries like Polars provide highly optimized functions for common data operations, you'll often need to use basic Python logic (like loops, conditional statements (`if`/`else`), and custom functions that you'll learn about soon) to perform specific data transformations, cleaning steps, or calculations that aren't directly built into the library.
#
# The Python fundamentals you're learning now are the necessary launching pad for effectively wielding the sophisticated data manipulation and analysis tools we'll explore in detail in the upcoming modules. You're building the foundation to work with data at scale!

# %% [markdown]
# # Section 5: Automating Tasks - Making Code Work for You
#
# So far, we've explored how to use Python's data types and structures to **model** real-world information (like customer details, product specifications, or financial figures). Now, let's shift our focus to the second anchor concept we introduced earlier: **Automation**.
#
# How do we instruct the computer to:
# * Make decisions based on the data we've modeled (e.g., "If sales are above target, calculate a bonus")?
# * Perform tasks repeatedly (e.g., "For every customer in our list, send a personalized welcome email")?
#
# This is where Python's **control flow statements** come into play. They allow us to dictate the order and conditions under which parts of our code are executed.

# %% [markdown]
# ## 5.1 Conditional Logic (`if`, `elif`, `else`)
#
# **Automation Motivation**: Often, the steps in an analysis, a business process, or a data transformation depend on certain conditions being met.
# * If a customer's total spending exceeds $500, classify them as "VIP".
# * If a financial metric is below a certain threshold, flag it for review.
# * If a survey response is "Strongly Agree", assign it a score of 5; if "Agree", assign 4, and so on.
#
# Conditional statements (`if`, `elif`, `else`) allow your Python program to make these kinds of decisions automatically based on whether specific conditions evaluate to `True` or `False`.

# %% [markdown]
# **The Core Idea**:
# These statements work by evaluating **boolean expressions** – expressions that result in `True` or `False` (often using the comparison `==, !=, <, >, <=, >=` and logical `and, or, not` operators we saw in Section 2.2).
#
# * The code block under an `if` statement runs *only if* its condition is `True`.
# * If the `if` condition is `False`, Python then checks the condition of the first `elif` (short for "else if"), if one is present. If that `elif` condition is `True`, its associated code block runs.
# * Python will check subsequent `elif` conditions only if all preceding `if` and `elif` conditions were `False`.
# * The `else` code block (if present) runs *only if* all the preceding `if` and `elif` conditions were `False`.

# %% [markdown]
# **Syntax (Indentation is Crucial!)**:
# Pay close attention to the **colons (`:`)** at the end of the `if`, `elif`, and `else` lines, and the **consistent indentation** (typically 4 spaces) for the code blocks belonging to each statement. Indentation is how Python groups blocks of code.
#
# ```python
# # General syntax structure
# if some_boolean_condition:
#     # This block runs ONLY if some_boolean_condition is True
#     # ... actions to take if true ...
# elif another_boolean_condition:
#     # This block runs ONLY if the 'if' was False AND 'another_boolean_condition' is True
#     # ... actions to take if this elif is true ...
# elif yet_another_condition:
#     # ... and so on for more elifs ...
# else:
#     # This block runs ONLY if ALL preceding 'if' AND 'elif' conditions were False
#     # ... actions to take if none of the above were true ...
# ```

# %%
# Example 1: Simple If statement
project_status = "Complete"
budget_remaining = 5000

if project_status == "Complete":
    print("Project is marked as complete.")
    # Further actions for completed projects could go here
    # e.g., archive_project_files(project_id)

if budget_remaining > 0:
    print(f"Project has ${budget_remaining:.2f} remaining in its budget.")

# %%
# Example 2: If-Else statement
inventory_count = 35
reorder_threshold = 50

if inventory_count < reorder_threshold:
    print(f"Stock alert: Inventory count ({inventory_count}) is below reorder threshold ({reorder_threshold}). Initiating reorder.")
    # e.g., place_new_order(product_id, quantity_to_order)
else:
    print(f"Stock level OK: Inventory count ({inventory_count}) is sufficient.")

# %%
# Example 3: If-Elif-Else statement
customer_satisfaction_score = 4 # Score from 1 (Very Unsatisfied) to 5 (Very Satisfied)
feedback_category = "" # Initialize an empty string

if customer_satisfaction_score == 5:
    feedback_category = "Very Satisfied"
    print("Action: Send a thank you note and request a testimonial!")
elif customer_satisfaction_score == 4:
    feedback_category = "Satisfied"
    print("Action: Good to know. Monitor for future trends.")
elif customer_satisfaction_score == 3:
    feedback_category = "Neutral"
    print("Action: Consider a follow-up survey to understand concerns.")
elif customer_satisfaction_score == 2:
    feedback_category = "Unsatisfied"
    print("Action: Escalate to customer support for immediate follow-up!")
else: # Covers score 1 or any other unexpected value
    feedback_category = "Very Unsatisfied / Critical"
    print("Action: URGENT - Escalate to senior management and customer retention team!")

print(f"\nCustomer Feedback Category Determined: {feedback_category}")

# %% [markdown]
# ## 5.2 Iteration: Repeating Actions
#
# **Automation Motivation**: Many, if not most, data-related tasks involve performing the same operation on multiple pieces of data.
# * Applying a discount to every product in a specific category.
# * Checking the data quality of every row in a dataset.
# * Processing each transaction in a sales log to calculate daily totals.
#
# Doing this manually is impractical and error-prone. **Iteration** allows you to automate these repetitive processes using **loops**. Python has two main types of loops: `for` loops and `while` loops.

# %% [markdown]
# ### `for` Loops: Iterating Over Sequences (The Workhorse)
# The `for` loop is the most common and idiomatic way to iterate (i.e., "loop over") items in Python, especially when working with sequences or collections like lists, tuples, strings, or dictionaries. It lets you process each item in a collection one by one.
#
# **Syntax**:
# ```python
# for temporary_variable in sequence_or_iterable:
#     # This indented code block runs ONCE for EACH item
#     # in the 'sequence_or_iterable'.
#     # Inside the loop, 'temporary_variable' holds the current item being processed.
#     # ... actions to perform on/with temporary_variable ...
# print("Loop finished.") # This line runs after all items have been processed
# ```

# %%
# Iterating over a List of customer segments
customer_segments = ["Enterprise", "SMB", "Startups", "Individual Pro"]
print("--- Marketing Outreach Plan ---")

for segment in customer_segments:
    # Inside the loop, 'segment' will hold "Enterprise" in the first iteration,
    # "SMB" in the second, and so on.
    print(f"Developing targeted campaign for: {segment} segment.")
print("--- Outreach plan drafted ---\n")

# %%
# Iterating over a String (strings are sequences of characters)
company_ticker = "ACME"
print(f"--- Characters in Ticker: {company_ticker} ---")
for character in company_ticker:
    print(f"Character: {character}")
print("--- End of ticker ---\n")

# %%
# Using range() to loop a specific number of times
# range(n) generates a sequence of numbers from 0 up to (but not including) n.
print("--- Processing 3 Quarterly Reports ---")
for quarter_number_idx in range(3): # Generates 0, 1, 2
    # We add 1 because humans usually count quarters starting from 1
    print(f"Starting analysis for Quarter {quarter_number_idx + 1}")
    # Code to process the report for this quarter would go here
print("--- All quarterly reports processed ---\n")

# %%
# range(start, stop) generates numbers from 'start' up to (but not including) 'stop'.
print("--- Calculating Compounded Interest for Years ---")
initial_investment = 1000.00
annual_interest_rate = 0.05 # 5%
investment_value = initial_investment

for year in range(1, 6): # Generates 1, 2, 3, 4, 5 (for 5 years)
    interest_earned = investment_value * annual_interest_rate
    investment_value += interest_earned # investment_value = investment_value + interest_earned
    print(f"Year {year}: Value = ${investment_value:,.2f} (Interest Earned: ${interest_earned:,.2f})")
print(f"--- Final investment value after 5 years: ${investment_value:,.2f} ---\n")

# %%
# Iterating over Dictionary Items
product_info = {"id": "XYZ-123", "name": "Premium Widget", "price_usd": 29.99, "category": "Electronics"}

print("--- Product Information (Keys) ---")
# Looping directly over a dictionary iterates through its keys by default
for key in product_info:
    print(f"Key: {key}")

print("\n--- Product Information (Values) ---")
# To get values, use the .values() method
for value in product_info.values():
    print(f"Value: {value}")

print("\n--- Product Information (Key-Value Pairs) ---")
# To get both keys and values, use the .items() method, which gives (key, value) tuples
for key, value in product_info.items():
    print(f"{key}: {value}")
print("--- End of product info ---")

# %% [markdown]
# ### `while` Loops: Repeating While a Condition is True
# A `while` loop repeatedly executes its code block *as long as* a specified boolean condition remains `True`. They are less common than `for` loops for simply iterating over existing data collections but are useful when you don't know in advance how many times you need to loop, or when the loop's continuation depends on some state that changes *within* the loop.
#
# **Syntax**:
# ```python
# while some_boolean_condition:
#     # Code block runs repeatedly as long as 'some_boolean_condition' is True
#     # ... actions to perform ...
#     # --- VERY IMPORTANT ---
#     # Something inside this block MUST eventually make
#     # 'some_boolean_condition' False, otherwise you have an infinite loop!
#     # --- VERY IMPORTANT ---
# print("Condition became False, while loop ended.")
# ```
# Warning: Be very cautious with while loops. If the condition never becomes False, the loop will run forever (an "infinite loop"). Your program will get stuck, and in Colab, you'll likely need to interrupt the execution (Runtime -> Interrupt execution or click the stop button). For iterating a known number of times or over existing sequences, for loops are generally preferred and safer.

# %%
# Example: Simulate processing items from a task queue until it's empty
# (A list can serve as a simple queue here)
data_processing_queue = ["DatasetA.csv", "DatasetB.json", "DatasetC.xml", "DatasetD.parquet"]
processed_files_count = 0

print("--- Starting Data Processing Queue ---")
while len(data_processing_queue) > 0: # Condition: loop as long as the queue is not empty
    # Get the next file to process (and remove it from the queue)
    # list.pop(0) removes and returns the item at index 0 (the "front" of the queue)
    current_file = data_processing_queue.pop(0)

    print(f"Processing: {current_file}...")
    # Simulate some processing time or action
    # In a real scenario, you'd load and analyze the file here.
    # For this example, we'll just increment a counter.
    processed_files_count += 1

    print(f"Remaining files in queue: {len(data_processing_queue)}")

print(f"\n--- Finished processing queue. Total files processed: {processed_files_count} ---")


# Example: A simple countdown (less practical, but shows the structure)
countdown = 3
print("\n--- Launch Countdown ---")
while countdown > 0:
    print(f"{countdown}...")
    countdown -= 1 # Crucial: This changes the condition variable towards False
print("Liftoff!")

# %% [markdown]
# Loops (`for` and `while`) are the true engines of automation in programming. They empower you to handle large amounts of data, perform complex repetitive procedures, and build dynamic systems with concise and efficient code.

# %% [markdown]
#  __Interacting with Attributes and Methods of Objects__

# %%
# String object (instance of 'str' class)
company_motto = "  Innovate for a Better Tomorrow!  "
print(f"Original Motto: '{company_motto}'")

# Calling a METHOD of the string object: .strip()
cleaned_motto = company_motto.strip() # .strip() is a function belonging to string objects
print(f"Cleaned Motto (using .strip() method): '{cleaned_motto}'")

# Calling another METHOD: .upper()
uppercase_motto = cleaned_motto.upper()
print(f"Uppercase Motto (using .upper() method): '{uppercase_motto}'")

# %%
# List object (instance of 'list' class)
monthly_profits_usd = [12000, 15000, 13500, 16000]
print(f"\nOriginal Monthly Profits: {monthly_profits_usd}")

# Calling a METHOD of the list object: .append()
monthly_profits_usd.append(17500) # .append() modifies the list object directly
print(f"Profits after .append(17500) method: {monthly_profits_usd}")

# Calling another METHOD: .sort()
monthly_profits_usd.sort(reverse=True) # .sort() sorts the list in place
print(f"Profits after .sort(reverse=True) method: {monthly_profits_usd}")

# %%
# datetime.date object (instance of 'date' class from the datetime module)
# (ensure 'import datetime as dt' has been run previously)
invoice_date = dt.date(2025, 7, 22)
print(f"\nInvoice Date Object: {invoice_date}")

# Accessing ATTRIBUTES of the date object
print(f"Invoice Year (attribute): {invoice_date.year}")
print(f"Invoice Month (attribute): {invoice_date.month}")
print(f"Invoice Day (attribute): {invoice_date.day}")

# Calling a METHOD of the date object: .weekday()
# Monday is 0 and Sunday is 6
day_of_week = invoice_date.weekday()
print(f"Day of the week (method .weekday()): {day_of_week} (0=Mon, 1=Tue, ...)")

# %% [markdown]
#  __Conceptual examples of how this applies to Data Analysis libraries (like Polars)__
#
# You don't need to run these Polars lines yet; they are for illustration.

# %% [markdown]
# # Section 6: Structuring Code - For Reusability and Clarity
#
# As your data analysis tasks become more involved, you'll quickly find that writing all your code as one long sequence of commands becomes unwieldy. Well-structured code is:
# * **Easier to read and understand**: Both for yourself (when you revisit it later) and for others.
# * **Easier to maintain and debug**: If something goes wrong, it's simpler to pinpoint the issue in a well-organized structure.
# * **More reusable**: You can take parts of your code and apply them to new problems without rewriting everything.
#
# A core principle in programming is **DRY (Don't Repeat Yourself)**. If you find yourself copying and pasting blocks of code, it's often a sign that there's a better way to structure it. Python offers tools like functions and leverages concepts from Object-Oriented Programming to help manage complexity and promote reusability.

# %% [markdown]
# ## 6.1 Functions: Creating Reusable Commands
#
# **Motivation**: Imagine you need to perform the same specific calculation (like calculating a profit margin, standardizing a customer address, or converting units) at several different points in your analysis. Instead of writing the same lines of code repeatedly, you can package that logic into a **function**.
#
# **Benefits of Functions**:
# * **DRY (Don't Repeat Yourself)**: Define a block of code once and then **call** it by its name whenever you need it, potentially with different inputs.
# * **Modularity & Readability**: Breaking a large analysis down into smaller, well-named functions makes the overall workflow much easier to understand, test, and debug. Each function handles one specific part of the job.
# * **Abstraction**: When you call a function, you can focus on *what* it does (e.g., `calculate_net_profit(revenue, costs)`) rather than getting bogged down in the specific lines of code detailing *how* it does it.

# %% [markdown]
# ### Defining a Function
# You create your own functions using the `def` keyword. Here's the general syntax:
# ```python
# def function_name(parameter1, parameter2, ...):
#     """Optional: A docstring explaining what the function does, its args, and what it returns."""
#     # --- Indented function body ---
#     # Code to perform the function's task goes here.
#     # This code only runs when the function is CALLED.
#     # It can use the input parameters.
#     # variable_to_return = ... some calculation ...
#     return variable_to_return # Use 'return' to send a value back out
# ```
#
# **`def`**  The keyword that starts a function definition.
#
# **`function_name`** Give your function a descriptive name (use snake_case, e.g., calculate_roi, clean_text_data).
#
# **`(parameter1, parameter2, ...)`** Inside the parentheses are parameters – these are variables that act as placeholders for the inputs the function will receive when it's called. A function can have zero, one, or many parameters.
#
# **`:`** A colon ends the function definition line.
#
# **`Indented Body**` All the code belonging to the function must be consistently indented (usually 4 spaces). This is how Python knows which lines of code are part of the function.
#
# **`"""Docstring"""`** (Optional but Highly Recommended!): A triple-quoted string right after the def line is called a docstring. It's used to document what the function does, what its parameters represent, and what value(s) it returns. Good docstrings make your code much easier to understand and use.
#
# **`return value`** The return statement exits the function and sends a specified value back to the part of the code that called the function. If a function doesn't have a return statement, it implicitly returns a special value called None.

# %% [markdown]
# ### **Calling a Function**
#
# To execute the code inside a function, you call it by using its name followed by parentheses (). If the function expects parameters, you provide the actual input values (called arguments) inside these parentheses

# %%
# --- Defining a simple function ---
def greet_user(name):
    """Greets the user with their name."""
    message = f"Hello, {name}! Welcome to the MBA Data Analytics module."
    return message

# %%
# --- Calling the function ---
user_name = "Alex Chen"
welcome_message = greet_user(user_name) # 'user_name' is the argument passed to the 'name' parameter
print(welcome_message)

another_user = "Maria Rodriguez"
print(greet_user(another_user)) # We can call it multiple times with different arguments

# %%
# --- Defining a function for a common business calculation ---
def calculate_gross_profit_margin(revenue, cogs):
    """
    Calculates the gross profit margin as a percentage.

    Args:
        revenue (float): Total revenue.
        cogs (float): Cost of Goods Sold.

    Returns:
        float: Gross profit margin (e.g., 0.25 for 25%), or None if revenue is zero.
    """
    if revenue == 0:
        print("Warning: Revenue is zero, cannot calculate margin.")
        return None # Return None if division by zero would occur

    gross_profit = revenue - cogs
    margin = gross_profit / revenue
    return margin # Returns the calculated margin

# %%
# --- Calling the calculation function ---
company_A_revenue = 500000.00
company_A_cogs = 350000.00
margin_A = calculate_gross_profit_margin(company_A_revenue, company_A_cogs)

# Good practice to check if a function could return None
if margin_A is not None:
    print(f"Company A Gross Profit Margin: {margin_A:.2%}") # :.2% formats as percentage

company_B_revenue = 750000.00
company_B_cogs = 600000.00
margin_B = calculate_gross_profit_margin(company_B_revenue, company_B_cogs)
if margin_B is not None:
    print(f"Company B Gross Profit Margin: {margin_B:.2%}")

company_C_revenue = 0.00 # Example with zero revenue
company_C_cogs = 10000.00
margin_C = calculate_gross_profit_margin(company_C_revenue, company_C_cogs)
if margin_C is not None:
    print(f"Company C Gross Profit Margin: {margin_C:.2%}")
else:
    print("Company C margin could not be calculated.")

# %%
# --- Example: Reusable Age Calculation Function (using datetime) ---
import datetime as dt # Make sure datetime is imported

def calculate_age_from_dob(date_of_birth_str, date_format="%Y-%m-%d"):
  """
  Calculates the current age in years given a date_of_birth string.

  Args:
    date_of_birth_str (str): The date of birth as a string.
    date_format (str): The format of the date_of_birth_str (e.g., "%Y-%m-%d").

  Returns:
    int: The age in years, or None if the date_of_birth_str is invalid or None.
  """
  if date_of_birth_str is None:
    return None

  try:
    # Convert the string to a datetime.date object
    date_of_birth = dt.datetime.strptime(date_of_birth_str, date_format).date()
  except ValueError:
    print(f"Error: Invalid date string '{date_of_birth_str}' or format '{date_format}'.")
    return None # Handle incorrect input type or format

  today = dt.date.today()
  age = today.year - date_of_birth.year

  # Adjust if the birthday hasn't occurred yet this year
  if (today.month, today.day) < (date_of_birth.month, date_of_birth.day):
    age -= 1
  return age

# %%
# --- Calling the age calculation function ---
dob_person1_str = "1988-10-25"
age_person1 = calculate_age_from_dob(dob_person1_str)
if age_person1 is not None:
    print(f"Person 1 (Born {dob_person1_str}) Age: {age_person1}")

dob_person2_str = "2002-03-15"
age_person2 = calculate_age_from_dob(dob_person2_str)
if age_person2 is not None:
    print(f"Person 2 (Born {dob_person2_str}) Age: {age_person2}")

invalid_dob_str = "1990/12/31" # Incorrect format for the default
age_invalid = calculate_age_from_dob(invalid_dob_str) # This will print an error and return None

# %%
# Using a different date format
dob_person3_str = "15/07/1975"
age_person3 = calculate_age_from_dob(dob_person3_str, date_format="%d/%m/%Y")
if age_person3 is not None:
    print(f"Person 3 (Born {dob_person3_str}, using dd/mm/yyyy) Age: {age_person3}")

# %% [markdown]
# ## 6.2 A Glimpse into Objects & Classes (Understanding Our Libraries)
#
# Our `calculate_gross_profit_margin` function is useful. However, you might notice that the function logically "belongs" with the financial data (revenue, COGS) it operates on. This idea of bundling **data** together with the **functions (actions)** that are relevant to that data is the core concept behind **Object-Oriented Programming (OOP)**.
#
# You've actually been using objects extensively since the beginning of this notebook!
# * `"some text"` is an **object** of the `str` (string) type (or class).
# * `[10, 20, 30]` is an **object** of the `list` type.
# * `dt.date(2025, 5, 14)` creates an **object** of the `date` type (from the `datetime` module).

# %% [markdown]
# ### Class vs. Object (Blueprint vs. Instance)
#
# * A **Class** is like a blueprint, template, or category definition. It specifies:
#     * What *kind of data* (called **attributes**) objects of this class will hold.
#     * What *kind of actions* (called **methods**) objects of this class can perform.
#     * Examples of classes we've encountered: `str`, `int`, `list`, `dict`, `datetime.date`.
#     * When we use libraries like Polars, we'll encounter important classes like `DataFrame` and `Series`.
#
# * An **Object** is a specific *instance* created from a Class blueprint. Each object holds its own specific data values (its attributes are set) based on the blueprint defined by its class.
#     * Examples:
#         * `my_company_name = "FutureCorp"` ( `my_company_name` is an object/instance of the `str` class).
#         * `quarterly_sales = [10000, 12000, 11500]` (`quarterly_sales` is an object/instance of the `list` class).
#         * `report_date = dt.date(2025, 12, 31)` (`report_date` is an object/instance of the `date` class).

# %% [markdown]
# ### Attributes and Methods (An Object's Data and Actions)
#
# Objects typically encapsulate both data and actions. You interact with these using **dot notation (`.`):**
#
# 1.  **Attributes**: These are data values stored *inside* the object. They represent the state or characteristics of the object. You access them using `object_name.attribute_name`.
#
# 2.  **Methods**: These are functions that are "attached" to the object. They typically operate on the object's data (its attributes) or perform an action related to the object's purpose. You **call** methods using `object_name.method_name(arguments)` – notice the crucial **parentheses `()`** at the end (even if the method takes no arguments).

# %%
# --- Interacting with Attributes and Methods of Objects ---

# String object (instance of 'str' class)
company_motto = "  Innovate for a Better Tomorrow!  "
print(f"Original Motto: '{company_motto}'")

# Calling a METHOD of the string object: .strip()
cleaned_motto = company_motto.strip() # .strip() is a function belonging to string objects
print(f"Cleaned Motto (using .strip() method): '{cleaned_motto}'")

# Calling another METHOD: .upper()
uppercase_motto = cleaned_motto.upper()
print(f"Uppercase Motto (using .upper() method): '{uppercase_motto}'")

# %%
# List object (instance of 'list' class)
monthly_profits_usd = [12000, 15000, 13500, 16000]
print(f"\nOriginal Monthly Profits: {monthly_profits_usd}")

# Calling a METHOD of the list object: .append()
monthly_profits_usd.append(17500) # .append() modifies the list object directly
print(f"Profits after .append(17500) method: {monthly_profits_usd}")

# Calling another METHOD: .sort()
monthly_profits_usd.sort(reverse=True) # .sort() sorts the list in place
print(f"Profits after .sort(reverse=True) method: {monthly_profits_usd}")

# %%
# datetime.date object (instance of 'date' class from the datetime module)
# (ensure 'import datetime as dt' has been run previously)
invoice_date = dt.date(2025, 7, 22)
print(f"\nInvoice Date Object: {invoice_date}")

# Accessing ATTRIBUTES of the date object
print(f"Invoice Year (attribute): {invoice_date.year}")
print(f"Invoice Month (attribute): {invoice_date.month}")
print(f"Invoice Day (attribute): {invoice_date.day}")

# Calling a METHOD of the date object: .weekday()
# Monday is 0 and Sunday is 6
day_of_week = invoice_date.weekday()
print(f"Day of the week (method .weekday()): {day_of_week} (0=Mon, 1=Tue, ...)")

# --- Conceptual examples of how this applies to Data Analysis libraries (like Polars) ---
# You don't need to run these Polars lines yet; they are for illustration.

# Imagine 'sales_df' is a Polars DataFrame object (we'll learn to create these later)
# sales_df = pl.DataFrame(...) # This would create a DataFrame object

# %%
# prompt: replace ... in this code `sales_df = pl.DataFrame(...)`. the data frame should have a column Revenue. make up few more relevant columns. I should be able to run this code after you create the dataframe `sales_df.filter(pl.col("Revenue") > 10000)`

import datetime as dt
import polars as pl

# creating a DataFrame object
sales_df = pl.DataFrame({
    "Revenue": [12000, 15000, 8000, 20000, 11000, 18000],
    "Date": [dt.date(2024, 1, 15), dt.date(2024, 2, 20), dt.date(2024, 3, 10), dt.date(2024, 4, 5), dt.date(2024, 5, 1), dt.date(2024, 6, 25)],
    "Product": ["A", "B", "A", "C", "B", "C"],
    "Region": ["North", "South", "North", "East", "South", "East"],
    "UnitsSold": [100, 150, 70, 200, 90, 160]
})

# sales_df.filter(pl.col("Revenue") > 10000)


# Accessing an ATTRIBUTE of a DataFrame: .shape (gives rows, columns)
print(f"Shape of sales data (attribute): {sales_df.shape}")

# Accessing another ATTRIBUTE: .columns (gives list of column names)
print(f"Columns in sales data (attribute): {sales_df.columns}")

# Calling a METHOD of a DataFrame: .head() (shows first few rows)
print(f"First 5 rows of sales data (method):\n{sales_df.head(3)}")

# Calling another METHOD: .filter() (selects rows based on a condition)
filtered_sales_df = sales_df.filter(pl.col("Revenue") > 10000)
print(f"Sales data where Revenue > 10000 (method):\n{filtered_sales_df}")

# %% [markdown]
# ### The Key Takeaway for This Course (Practical OOP for MBA Students)
#
# You **do not need to become an expert** in designing or writing your own elaborate classes from scratch in this introductory data science course. That's a more advanced programming topic.
#
# However, it is **absolutely essential** for your success in data analysis using Python that you:
#
# 1.  Understand the core concept that **objects bundle data (attributes) and actions (methods)**.
# 2.  Become comfortable with the **dot notation syntax** for:
#     * Accessing an object's data: `object_name.attribute_name`
#     * Calling an object's actions: `object_name.method_name(arguments)` (don't forget the `()`)!
#
# **Why is this so critical for you as an MBA student learning data science?**
#
# Because the powerful data science libraries you will rely on – **Polars, Altair (for visualization), Scikit-learn (for machine learning)** – are fundamentally object-oriented. Your entire workflow when using these libraries will involve:
#
# * **Creating library objects**:
#     * `my_dataframe = pl.DataFrame(data)` (You create a DataFrame object)
#     * `my_chart = alt.Chart(my_dataframe).mark_bar(...)` (You create a Chart object)
#     * `my_model = sklearn.linear_model.LinearRegression()` (You create a Model object)
# * **Inspecting their data using attributes**:
#     * `print(my_dataframe.columns)` (See the column names)
#     * `print(my_dataframe.shape)` (See the number of rows and columns)
#     * `print(my_model.coef_)` (See the coefficients of a trained model)
# * **Telling them what to do by calling their methods**:
#     * `cleaned_df = my_dataframe.drop_nulls()`
#     * `summary_stats = my_dataframe.describe()`
#     * `grouped_data = my_dataframe.group_by("Category").agg(pl.sum("Sales"))`
#     * `my_chart.save("sales_chart.png")`
#     * `my_model.fit(X_train, y_train)`
#     * `predictions = my_model.predict(X_test)`
#
# Grasping this user-level interaction with objects – knowing that they hold data you can look at (attributes) and have built-in capabilities you can trigger (methods) – is the "practical OOP" you need to unlock the power of these essential data science tools. It's less about *being* an OOP expert and more about *using* what OOP provides in these libraries effectively.

# %% [markdown]
# # Section 7: Summary, Practice & Next Steps
#
# Congratulations! You've successfully navigated the foundational concepts of Python programming, specifically tailored for data analysis. We've approached this by focusing on two key practical skills: **Modeling Information** and **Automating Tasks**.

# %% [markdown]
# ## 7.1 Recap: Your Python Foundation
#
# Let's quickly summarize the essential Python building blocks and concepts we've covered in this introductory notebook:
#
# * **Why Python & Our Approach**: Understanding the role of Python in data-driven decision-making and our focus on modeling information and automating tasks.
# * **Modeling Fundamentals**:
#     * Basic data types (`int`, `float`, `str`, `bool`, `None`).
#     * Representing raw information (literals) and giving it meaningful names using variables (`=`).
#     * Using expressions and operators for calculations (`+`, `-`, `*`, `/`, `**`, `%`, `//`) and comparisons (`==`, `!=`, `<`, `>`, `<=`, `>=`).
#     * Working with text (`str` methods like `.strip()`, `.lower()`, `.upper()`, `.replace()`, and `f-strings` for formatting).
# * **Modeling Structures**:
#     * Organizing ordered, changeable collections with `list` (indexing, slicing, `.append()`).
#     * Representing ordered, *un*changeable records with `tuple`.
#     * Storing labeled information (key-value pairs) in `dict` (accessing by key, adding/modifying entries).
# * **Task Automation**:
#     * Making decisions in your code using conditional logic (`if`, `elif`, `else`).
#     * Repeating actions over sequences or based on conditions using loops (`for` loops with sequences and `range()`, basic `while` loops).
# * **Structuring Code**:
#     * Creating reusable blocks of code with functions (`def`, parameters, `return`, docstrings).
#     * A practical introduction to Object-Oriented Programming (OOP): Understanding that objects (like strings, lists, dates, and library objects we'll soon use) have data (**attributes**, accessed via `object.attribute`) and actions (**methods**, called via `object.method()`).
# * **Essential Practices**:
#     * Importing modules to access more tools (`import ... as ...`).
#     * Writing comments (`#`) to explain your code.
#     * Understanding the Colab environment's execution model.
#
# You now possess the fundamental vocabulary and grammatical rules of Python needed to start commanding the computer to perform data-related work. This is a significant first step!

# %% [markdown]
# ## 7.2 Practice Assignment: Consolidate Your Learning
#
# To help you solidify your understanding of the concepts covered in this notebook, here's a small hands-on practice assignment. The goal is to apply what you've learned to solve a few simple problems. Please add new code cells below these instructions to write and run your Python code for each task.
#
# **Instructions:**
#
# **Task 1: Company Profile & Product Details**
#
# 1.  **Company Information (Variables & Data Types):**
#     * Create variables to store the following information for a hypothetical company:
#         * `company_name` (string, e.g., "Innovatech Solutions")
#         * `year_founded` (integer, e.g., 2015)
#         * `is_publicly_traded` (boolean, e.g., `False`)
#         * `initial_funding_usd` (float, e.g., 750000.50)
#     * Print each of these variables with a descriptive label using f-strings.
#
# 2.  **Product Line (Lists):**
#     * Create a list called `product_names` containing at least three product names (strings) offered by the company (e.g., "AlphaWidget", "BetaService", "GammaPlatform").
#     * Print the second product in the list.
#     * Add a new product, "DeltaTool", to the end of the `product_names` list.
#     * Print the updated `product_names` list.
#
# 3.  **Specific Product Record (Tuples):**
#     * Represent a specific, fixed record for one of your products as a tuple called `product_record`. This tuple should contain: `(product_id_str, launch_year_int, initial_price_float)`.
#         * Example: `("AW001", 2022, 499.99)`
#     * Print this `product_record`.
#
# 4.  **Product Specifications (Dictionaries):**
#     * Create a dictionary called `product_specs` for one of your products. It should include at least three key-value pairs:
#         * `'name'` (string, e.g., the product name from your list)
#         * `'category'` (string, e.g., "Software", "Hardware", "Service")
#         * `'features'` (a list of strings, e.g., `["Feature A", "Feature B", "Scalable"]`)
#         * `'base_price_usd'` (float)
#     * Print the `product_specs` dictionary.
#     * Update the `'base_price_usd'` to a new value (e.g., increase it by 10%).
#     * Add a new key-value pair: `'status'` with a string value (e.g., "Active" or "In Development").
#     * Print the updated `product_specs` dictionary.
#
# **Task 2: Sales Commission Calculator (Conditional Logic & Loops)**
#
# 1.  **Sales Data (List of Dictionaries):**
#     * Create a list of dictionaries called `sales_reps_data`. Each dictionary should represent a sales representative and contain:
#         * `'name'` (string)
#         * `'region'` (string, e.g., "North", "South", "East", "West")
#         * `'monthly_sales_usd'` (float)
#     * Include at least 3 sales reps in your list. Example:
#         ```python
#         # sales_reps_data = [
#         #     {'name': 'John Doe', 'region': 'North', 'monthly_sales_usd': 12000.00},
#         #     # ... more reps ...
#         # ]
#         ```
#
# 2.  **Commission Calculation (For Loop & If-Elif-Else):**
#     * Iterate through your `sales_reps_data` list using a `for` loop.
#     * Inside the loop, for each sales rep, calculate their commission based on their `monthly_sales_usd`:
#         * If sales are > $15,000, commission is 10% of sales.
#         * If sales are > $10,000 but <= $15,000, commission is 7% of sales.
#         * If sales are <= $10,000, commission is 5% of sales.
#     * For each sales rep, print their name, their sales, and their calculated commission (formatted nicely, e.g., as currency).
#
# **Task 3: Client Feedback Formatter (Functions)**
#
# 1.  **Define a Function:**
#     * Define a function called `format_client_feedback`.
#     * This function should take two arguments: `client_name` (string) and `feedback_text` (string).
#     * Inside the function:
#         * Convert the `client_name` to uppercase.
#         * Ensure the `feedback_text` starts with a capital letter and ends with a period (even if it already does or doesn't). (Hint: string methods!)
#         * The function should `return` a formatted string like: `"Feedback from CLIENT NAME: Formatted feedback text."`
# 2.  **Call the Function:**
#     * Call your `format_client_feedback` function with at least two different examples of client names and feedback text.
#     * Print the results returned by the function.
#
# **Good luck! Remember to add comments to your code to explain your steps.**
#
# *(Your instructor will provide details on submission if this assignment is graded.)*

# %% [markdown]
# ## 7.3 Looking Ahead: Applying Python to Data
#
# This introduction to Python is the essential groundwork, not just an abstract exercise. Every concept we've discussed – from variables and data types to loops, functions, and the basics of object interaction – directly enables the real-world data analysis we'll be doing next.
#
# In our upcoming sessions (often referred to as **Module 2: Exploratory Data Analysis - EDA**), we will immediately start applying these Python foundations as we learn to use powerful, industry-standard libraries:
#
# * **Polars**:
#     * You've had a small teaser of Polars. Soon, you'll see how Polars uses concepts similar to Python lists and dictionaries to create highly efficient **Series** (columns) and **DataFrames** (tables).
#     * Your understanding of Python's data types, data structures (like lists of dictionaries for creating DataFrames), iteration (for custom operations), and interacting with objects (calling methods like `.filter()`, `.select()`, `.group_by()` on DataFrame objects) will be absolutely crucial.
#     * We'll use these skills to load massive datasets, clean messy real-world information, manipulate tables, group data, calculate summary statistics, and much more – all powered by Python and Polars.
#
# * **Altair (and other visualization libraries)**:
#     * To create compelling and insightful data visualizations, we'll leverage Python lists and dictionaries to structure the data for plotting.
#     * The object-oriented pattern you've just been introduced to (e.g., `my_chart_object.configure_axis().properties(...)`) is central to how many modern visualization libraries work.
#
# The journey ahead involves using these foundational Python skills as leverage to operate much more sophisticated tools. Get ready to transition from learning the language basics to applying them to explore, understand, and communicate insights from complex data!
#
# This is an exciting point in your data science journey. Keep practicing, stay curious, and don't hesitate to ask questions!
