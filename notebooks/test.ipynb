# %%
import numpy as np

# %% [markdown]
# ## Session 1: Items

# %% [markdown]
# - [ ] How to import files into colab
# - [ ] How to use Google Drive
# - [ ] How to use key vault
# - [ ] How to install dependencies (pip / uv)
# - [ ] Getting help - IDE auto complete, IDE quick docs, Documentation page, Gen AI, Search `CTRL + SHIFT + SPACE`
# - [ ] Use code snippets
# - [ ] How to write markdown in jupyter notebook
#     - [ ] explain table of contents feature and heading level
#     - [ ] explain code collapse and expand features `CTRL + [` `CTRL + ]` `CTRL + '`
#     - [ ] How to use markdown, table of contents, expand and collapse, gemini features to navigate a long sample from github.
#     - [ ] explain code, annotate with markdown, logical sections
# - [ ] Use scratch code cell for trying out things `ALT + CTRL + N`

# %% [markdown]
# ## Session 2: Items

# %% [markdown]
# - [ ] python scalar and collection vis-a-vis numpy and pandas
# - [ ] Python Data and control structures
# - [ ] Why Numpy: Efficient and Convenient linear algebra
# - [ ] What's the role of Pandas and how is it related to Numpy
# - [ ] What's the use of matplotlib and seaborn
# - [ ] pandas crosstab pivot
# - [ ] %debug
# - [ ] Different ways to import dependencies `from sklearn import (datasets, model_selection)`, `import pandas as pd`
# - [ ]

# %%
from sklearn import (datasets, model_selection)

# %% [markdown]
# ## Dig Deep:

# %% [markdown]
# - [ ] from sklearn import (datasets, model_selection)
# - [ ] from sklearn import neighbors
# - [ ] from sklearn import metrics
#     - [ ] cm = metrics.confusion_matrix(part2.tgt, preds)

# %% [markdown]
# ## Guessing game
# - [ ] to showcase linear algebra and connect it to regression concepts
# - [ ] dot product to calculate sum of squares,
# - [ ] dot product to calculate mean
# - [ ] error sum of squares and standard deviation
